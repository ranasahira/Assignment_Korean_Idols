# %% [markdown]
# # IMPORT PACKAGES

# %%
import pandas as pd
import numpy as np
import json
import requests

# %% [markdown]
# # IMPORT DATA API (KOREAN IDOLS)

# %%
data=pd.read_csv("korean_idols.csv")
data
# Out:
#   Stage Name          Full Name       Birth
# 0         IU          Lee Jieun  1993-05-16
# 1     Jennie         Kim Jennie  1996-01-16
# 2       Lisa  Pranpriya Manoban  1997-03-27
# 3      Jihyo         Park Jisoo  1997-02-01
# 4       Sana    Minatozaki Sana  1996-12-29
# 5      Tzuyu         Chou Tzuyu  1999-06-14
# 6     Dahyun         Kim Dahyun  1998-05-28
# 7        Bom           Park Bom  1984-03-24
# 8   Jungkook      Jeon Jungkook  1997-09-01
# 9          V       Kim Taehyung  1995-12-30

# %% [markdown]
# # GET DATA API

# %% [markdown]
# Because in data API resource has Required Parameters, so when we want to get complete data we must combine data with gender "female" and "male".

# %% [markdown]
# ## API DATA WITH FEMALE GENDER

# %%
url = "https://k-pop.p.rapidapi.com/idols"

querystring = {"q": "F" ,"by":"Gender"}

headers = {
	"X-RapidAPI-Key": "315564a229msh79219e8f9125acdp16837bjsn6fd6f0544501",
	"X-RapidAPI-Host": "k-pop.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

data1=response.json()
df= pd.json_normalize(data1, 'data')
df
# Out:
#                                                Profile Stage Name  \
# 0    https://dbkpop.com/idol/taeyeon-girls-generation/    Taeyeon
# 1                                                 None      Sunny
# 2                                                 None    Tiffany
# 3                                                 None    Hyoyeon
# 4                                                 None       Yuri
# ..                                                 ...        ...
# 783                                               None     Ririka
# 784                                               None       Nayu
# 785                                               None       Elva
# 786                                               None       Lily
# 787                                               None     Haewon
#
#            Full Name Korean Name K. Stage Name Date of Birth  Group  \
# 0        Kim Taeyeon        김태연            태연     1989-03-09   SNSD
# 1         Lee Sunkyu        이순규             써니    1989-05-15   SNSD
# 2      Hwang Miyoung         황미영           티파니    1989-08-01   SNSD
# 3        Kim Hyoyeon        김효연            효연     1989-09-22   SNSD
# 4          Kwon Yuri        권유리             유리    1989-12-05   SNSD
# ..               ...         ...           ...           ...    ...
# 783   Kishida Ririka     키시다 리리카           리리카    2002-07-02  ILY:1
# 784        Kim Yewon         김예원            나유    2002-07-23  ILY:1
# 785      Lee Yonghwa         이용화            엘바    2003-05-05  ILY:1
# 786  Lily Jin Morrow    릴리 진 머로우            릴리    2002-10-17  NMIXX
# 787        Oh Haewon         오해원            해원    2003-02-25  NMIXX
#
#          Country Second Country Height Weight     Birthplace Other Group  \
# 0    South Korea           None    160     44         Jeonju  TTS, Oh!GG
# 1    South Korea           None    158     43     California        None
# 2    South Korea            USA    163     50  San Francisco         TTS
# 3    South Korea           None    158     48        Incheon        None
# 4    South Korea           None    167     45         Goyang        None
# ..           ...            ...    ...    ...            ...         ...
# 783        Japan           None    162      0           None        None
# 784  South Korea           None      0      0           None        None
# 785  South Korea           None      0      0           None        None
# 786    Australia    South Korea      0      0     Marysville        None
# 787  South Korea           None      0      0           None        None
#
#     Former Group Gender               Position  \
# 0           None      F  Leader, Main Vocalist
# 1           None      F                   None
# 2           None      F                   None
# 3           None      F                   None
# 4           None      F                   None
# ..           ...    ...                    ...
# 783         None      F                   None
# 784         None      F                   None
# 785         None      F                   None
# 786         None      F                   None
# 787         None      F                   None
#
#                                  Instagram Twitter
# 0      https:/www.instagram.com/taeyeon_ss    None
# 1      https:/www.instagram.com/svnnynight    None
# 2    https:/www.instagram.com/xolovestephi    None
# 3     https:/www.instagram.com/watasiwahyo    None
# 4         https:/www.instagram.com/yulyulk    None
# ..                                     ...     ...
# 783                                   None    None
# 784                                   None    None
# 785                                   None    None
# 786                                   None    None
# 787                                   None    None
#
# [788 rows x 18 columns]

# %% [markdown]
# ## API DATA WITH MALE GENDER

# %%
url = "https://k-pop.p.rapidapi.com/idols"

querystring = {"q": "M" ,"by":"Gender"}

headers = {
	"X-RapidAPI-Key": "315564a229msh79219e8f9125acdp16837bjsn6fd6f0544501",
	"X-RapidAPI-Host": "k-pop.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

data2=response.json()
df1= pd.json_normalize(data2, 'data')
df1
# Out:
#     Profile Stage Name        Full Name Korean Name K. Stage Name  \
# 0      None      T.O.P   Choi Seunghyun         최승현             탑
# 1      None    Taeyang    Dong Youngbae         동영배            태양
# 2      None   G-Dragon      Kwon Jiyong         권지용          지드래곤
# 3      None    Daesung          Daesung         강대성            대성
# 4      None    Seungri    Lee Seunghyun         이승현            승리
# ..      ...        ...              ...         ...           ...
# 801    None       Hyuk      Koo Bonhyuk         구본혁             혁
# 802    None        Lew     Lee Euiwoong         이의웅             루
# 803    None    Hwarang       Son Jaewon         송재원            화랑
# 804    None    Eunchan  Choi Byeongseop         최병섭            은찬
# 805    None     Taerae       Kim Taerae         김태래            태래
#
#     Date of Birth    Group      Country Second Country Height Weight  \
# 0      1987-11-04  BIGBANG  South Korea           None    180     65
# 1      1988-05-18  BIGBANG  South Korea           None    174     56
# 2      1988-08-18  BIGBANG  South Korea           None    177     58
# 3      1989-04-26  BIGBANG  South Korea           None    178     63
# 4      1990-12-12  BIGBANG  South Korea           None    176     60
# ..            ...      ...          ...            ...    ...    ...
# 801    2000-04-17  TEMPEST  South Korea           None      0      0
# 802    2001-04-05  TEMPEST  South Korea           None    170     55
# 803    2001-04-23  TEMPEST  South Korea           None    179     61
# 804    2001-02-27  TEMPEST  South Korea           None    184      0
# 805    2002-09-05  TEMPEST  South Korea           None      0      0
#
#     Birthplace          Other Group Former Group Gender Position Instagram  \
# 0        Seoul               GD&TOP         None      M     None      None
# 1    Uljeongbu                 None         None      M     None      None
# 2        Seoul               GD&TOP         None      M     None      None
# 3      Incheon                 None         None      M     None      None
# 4      Gwangju                 None         None      M     None      None
# ..         ...                  ...          ...    ...      ...       ...
# 801       None                 None         None      M     None      None
# 802       None  HyeongseopXEuiwoong         None      M     None      None
# 803       None                 None         None      M     None      None
# 804       None                 None         None      M     None      None
# 805       None                 None         None      M     None      None
#
#     Twitter
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
# ..      ...
# 801    None
# 802    None
# 803    None
# 804    None
# 805    None
#
# [806 rows x 18 columns]

# %% [markdown]
# ## COMBINE DATA API FEMALE & MALE

# %%
korean_idols = pd.concat([df,df1])
korean_idols
# Out:
#                                                Profile Stage Name  \
# 0    https://dbkpop.com/idol/taeyeon-girls-generation/    Taeyeon
# 1                                                 None      Sunny
# 2                                                 None    Tiffany
# 3                                                 None    Hyoyeon
# 4                                                 None       Yuri
# ..                                                 ...        ...
# 801                                               None       Hyuk
# 802                                               None        Lew
# 803                                               None    Hwarang
# 804                                               None    Eunchan
# 805                                               None     Taerae
#
#            Full Name Korean Name K. Stage Name Date of Birth    Group  \
# 0        Kim Taeyeon        김태연            태연     1989-03-09     SNSD
# 1         Lee Sunkyu        이순규             써니    1989-05-15     SNSD
# 2      Hwang Miyoung         황미영           티파니    1989-08-01     SNSD
# 3        Kim Hyoyeon        김효연            효연     1989-09-22     SNSD
# 4          Kwon Yuri        권유리             유리    1989-12-05     SNSD
# ..               ...         ...           ...           ...      ...
# 801      Koo Bonhyuk         구본혁             혁    2000-04-17  TEMPEST
# 802     Lee Euiwoong         이의웅             루    2001-04-05  TEMPEST
# 803       Son Jaewon         송재원            화랑    2001-04-23  TEMPEST
# 804  Choi Byeongseop         최병섭            은찬    2001-02-27  TEMPEST
# 805       Kim Taerae         김태래            태래    2002-09-05  TEMPEST
#
#          Country Second Country Height Weight     Birthplace  \
# 0    South Korea           None    160     44         Jeonju
# 1    South Korea           None    158     43     California
# 2    South Korea            USA    163     50  San Francisco
# 3    South Korea           None    158     48        Incheon
# 4    South Korea           None    167     45         Goyang
# ..           ...            ...    ...    ...            ...
# 801  South Korea           None      0      0           None
# 802  South Korea           None    170     55           None
# 803  South Korea           None    179     61           None
# 804  South Korea           None    184      0           None
# 805  South Korea           None      0      0           None
#
#              Other Group Former Group Gender               Position  \
# 0             TTS, Oh!GG         None      F  Leader, Main Vocalist
# 1                   None         None      F                   None
# 2                    TTS         None      F                   None
# 3                   None         None      F                   None
# 4                   None         None      F                   None
# ..                   ...          ...    ...                    ...
# 801                 None         None      M                   None
# 802  HyeongseopXEuiwoong         None      M                   None
# 803                 None         None      M                   None
# 804                 None         None      M                   None
# 805                 None         None      M                   None
#
#                                  Instagram Twitter
# 0      https:/www.instagram.com/taeyeon_ss    None
# 1      https:/www.instagram.com/svnnynight    None
# 2    https:/www.instagram.com/xolovestephi    None
# 3     https:/www.instagram.com/watasiwahyo    None
# 4         https:/www.instagram.com/yulyulk    None
# ..                                     ...     ...
# 801                                   None    None
# 802                                   None    None
# 803                                   None    None
# 804                                   None    None
# 805                                   None    None
#
# [1594 rows x 18 columns]

# %%
ikorean_idols = korean_idols.reset_index(drop=True)
ikorean_idols
# Out:
#                                                 Profile Stage Name  \
# 0     https://dbkpop.com/idol/taeyeon-girls-generation/    Taeyeon
# 1                                                  None      Sunny
# 2                                                  None    Tiffany
# 3                                                  None    Hyoyeon
# 4                                                  None       Yuri
# ...                                                 ...        ...
# 1589                                               None       Hyuk
# 1590                                               None        Lew
# 1591                                               None    Hwarang
# 1592                                               None    Eunchan
# 1593                                               None     Taerae
#
#             Full Name Korean Name K. Stage Name Date of Birth    Group  \
# 0         Kim Taeyeon        김태연            태연     1989-03-09     SNSD
# 1          Lee Sunkyu        이순규             써니    1989-05-15     SNSD
# 2       Hwang Miyoung         황미영           티파니    1989-08-01     SNSD
# 3         Kim Hyoyeon        김효연            효연     1989-09-22     SNSD
# 4           Kwon Yuri        권유리             유리    1989-12-05     SNSD
# ...               ...         ...           ...           ...      ...
# 1589      Koo Bonhyuk         구본혁             혁    2000-04-17  TEMPEST
# 1590     Lee Euiwoong         이의웅             루    2001-04-05  TEMPEST
# 1591       Son Jaewon         송재원            화랑    2001-04-23  TEMPEST
# 1592  Choi Byeongseop         최병섭            은찬    2001-02-27  TEMPEST
# 1593       Kim Taerae         김태래            태래    2002-09-05  TEMPEST
#
#           Country Second Country Height Weight     Birthplace  \
# 0     South Korea           None    160     44         Jeonju
# 1     South Korea           None    158     43     California
# 2     South Korea            USA    163     50  San Francisco
# 3     South Korea           None    158     48        Incheon
# 4     South Korea           None    167     45         Goyang
# ...           ...            ...    ...    ...            ...
# 1589  South Korea           None      0      0           None
# 1590  South Korea           None    170     55           None
# 1591  South Korea           None    179     61           None
# 1592  South Korea           None    184      0           None
# 1593  South Korea           None      0      0           None
#
#               Other Group Former Group Gender               Position  \
# 0              TTS, Oh!GG         None      F  Leader, Main Vocalist
# 1                    None         None      F                   None
# 2                     TTS         None      F                   None
# 3                    None         None      F                   None
# 4                    None         None      F                   None
# ...                   ...          ...    ...                    ...
# 1589                 None         None      M                   None
# 1590  HyeongseopXEuiwoong         None      M                   None
# 1591                 None         None      M                   None
# 1592                 None         None      M                   None
# 1593                 None         None      M                   None
#
#                                   Instagram Twitter
# 0       https:/www.instagram.com/taeyeon_ss    None
# 1       https:/www.instagram.com/svnnynight    None
# 2     https:/www.instagram.com/xolovestephi    None
# 3      https:/www.instagram.com/watasiwahyo    None
# 4          https:/www.instagram.com/yulyulk    None
# ...                                     ...     ...
# 1589                                   None    None
# 1590                                   None    None
# 1591                                   None    None
# 1592                                   None    None
# 1593                                   None    None
#
# [1594 rows x 18 columns]

# %% [markdown]
# # CHECKING DATA

# %% [markdown]
# Checking data csv that was available to API Data

# %%
full_names= data.iloc[:,1].to_list()
full_names
# Out:
# ['Lee Jieun',
#  'Kim Jennie',
#  'Pranpriya Manoban',
#  'Park Jisoo',
#  'Minatozaki Sana',
#  'Chou Tzuyu',
#  'Kim Dahyun',
#  'Park Bom',
#  'Jeon Jungkook',
#  'Kim Taehyung']

# %%
data_finish=ikorean_idols[ikorean_idols['Full Name'].isin(full_names)].reset_index(drop=True)
data_finish
# Out:
#                                       Profile Stage Name          Full Name  \
# 0                                        None        Bom           Park Bom
# 1              https://dbkpop.com/idol/jihyo/      Jihyo         Park Jisoo
# 2               https://dbkpop.com/idol/sana/       Sana    Minatozaki Sana
# 3             https://dbkpop.com/idol/dahyun/     Dahyun         Kim Dahyun
# 4              https://dbkpop.com/idol/tzuyu/      Tzuyu         Chou Tzuyu
# 5                                        None         IU          Lee Jieun
# 6   https://dbkpop.com/idol/jennie-blackpink/     Jennie         Kim Jennie
# 7     https://dbkpop.com/idol/lisa-blackpink/       Lisa  Pranpriya Manoban
# 8              https://dbkpop.com/idol/v-bts/          V       Kim Taehyung
# 9       https://dbkpop.com/idol/jungkook-bts/   Jungkook      Jeon Jungkook
# 10        https://dbkpop.com/idol/jseph-kard/     J.seph       Kim Taehyung
#
#    Korean Name K. Stage Name Date of Birth      Group      Country  \
# 0           박봄             봄    1984-03-24       2NE1  South Korea
# 1          박지수            지효    1997-02-01      Twice  South Korea
# 2     미나토자키 사나            사나    1996-12-29      Twice        Japan
# 3          김다현            다현    1998-05-28      Twice  South Korea
# 4         저우쯔위            쯔위    1999-06-14      Twice       Taiwan
# 5          이지은           아이유    1993-05-16       None  South Korea
# 6          김제니            제니    1996-01-16  BLACKPINK  South Korea
# 7    쁘란쁘리야 마노반            리사    1997-03-27  BLACKPINK     Thailand
# 8          김태형             뷔    1995-12-30        BTS  South Korea
# 9          전정국            정국    1997-09-01        BTS  South Korea
# 10         김태형           제이셉    1992-06-21       KARD  South Korea
#
#    Second Country Height Weight Birthplace Other Group Former Group Gender  \
# 0            None      0      0       None        None         None      F
# 1            None    162      0       Guri        None         None      F
# 2            None    168      0      Osaka        None         None      F
# 3            None    165      0   Seongnam        None         None      F
# 4            None    169      0     Tainan        None         None      F
# 5            None    162      0      Seoul        None         None      F
# 6            None    163     50     Anyang        None         None      F
# 7            None    170     46    Bangkok        None         None      F
# 8            None    179     62      Daegu        None         None      M
# 9            None    178     66      Busan        None         None      M
# 10            USA      0      0       None        None         None      M
#
#               Position                            Instagram Twitter
# 0                 None  https:/www.instagram.com/haroobommi    None
# 1   Leader, Main Vocal                                 None    None
# 2                 None                                 None    None
# 3                 None                                 None    None
# 4                 None                                 None    None
# 5                 None     https:/www.instagram.com/dlwlrma    None
# 6                 None                                 None    None
# 7                 None                                 None    None
# 8                 None                                 None    None
# 9                 None                                 None    None
# 10                None                                 None    None

# %% [markdown]
# It can be seen that data csv "korean_idols" existing in API Data (in top 10 rows). But, we have duplicate full name in last row, so we want to drop that row.

# %%
data_finish.drop_duplicates(subset = 'Full Name')
# Out:
#                                      Profile Stage Name          Full Name  \
# 0                                       None        Bom           Park Bom
# 1             https://dbkpop.com/idol/jihyo/      Jihyo         Park Jisoo
# 2              https://dbkpop.com/idol/sana/       Sana    Minatozaki Sana
# 3            https://dbkpop.com/idol/dahyun/     Dahyun         Kim Dahyun
# 4             https://dbkpop.com/idol/tzuyu/      Tzuyu         Chou Tzuyu
# 5                                       None         IU          Lee Jieun
# 6  https://dbkpop.com/idol/jennie-blackpink/     Jennie         Kim Jennie
# 7    https://dbkpop.com/idol/lisa-blackpink/       Lisa  Pranpriya Manoban
# 8             https://dbkpop.com/idol/v-bts/          V       Kim Taehyung
# 9      https://dbkpop.com/idol/jungkook-bts/   Jungkook      Jeon Jungkook
#
#   Korean Name K. Stage Name Date of Birth      Group      Country  \
# 0          박봄             봄    1984-03-24       2NE1  South Korea
# 1         박지수            지효    1997-02-01      Twice  South Korea
# 2    미나토자키 사나            사나    1996-12-29      Twice        Japan
# 3         김다현            다현    1998-05-28      Twice  South Korea
# 4        저우쯔위            쯔위    1999-06-14      Twice       Taiwan
# 5         이지은           아이유    1993-05-16       None  South Korea
# 6         김제니            제니    1996-01-16  BLACKPINK  South Korea
# 7   쁘란쁘리야 마노반            리사    1997-03-27  BLACKPINK     Thailand
# 8         김태형             뷔    1995-12-30        BTS  South Korea
# 9         전정국            정국    1997-09-01        BTS  South Korea
#
#   Second Country Height Weight Birthplace Other Group Former Group Gender  \
# 0           None      0      0       None        None         None      F
# 1           None    162      0       Guri        None         None      F
# 2           None    168      0      Osaka        None         None      F
# 3           None    165      0   Seongnam        None         None      F
# 4           None    169      0     Tainan        None         None      F
# 5           None    162      0      Seoul        None         None      F
# 6           None    163     50     Anyang        None         None      F
# 7           None    170     46    Bangkok        None         None      F
# 8           None    179     62      Daegu        None         None      M
# 9           None    178     66      Busan        None         None      M
#
#              Position                            Instagram Twitter
# 0                None  https:/www.instagram.com/haroobommi    None
# 1  Leader, Main Vocal                                 None    None
# 2                None                                 None    None
# 3                None                                 None    None
# 4                None                                 None    None
# 5                None     https:/www.instagram.com/dlwlrma    None
# 6                None                                 None    None
# 7                None                                 None    None
# 8                None                                 None    None
# 9                None                                 None    None
